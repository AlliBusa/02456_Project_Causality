# %%
# %run DL_func.ipynb

# %%
from sklearn.metrics import r2_score

# %% [markdown]
# The first step consists of generating the synthetic data. The data is generated from the graph shown belown. Z denotes the unobserved latent variables, Y is the target variable which will be assumed observed (i.e. in the cow/camel classification problem 'Y' will correspond to the label 'cow' / 'camel'). X is the observed features as is generated from Z via a neural network. In the cow / camel classification problem 'X' would correspond to the actual image. Finally, an environment variable E is introduced. The environment determines the mean of the gaussian distribution the Z's are drawn from. The generative process for each of the variables is as follows:
#
# $$Z_1 = \mathcal{N}(E, \sigma=1)$$
# $$Z_2 = \mathcal{N}(2E, \sigma=2)$$
# $$Y = \mathcal{N}(\alpha_1 \cdot Z_1+\alpha_2 \cdot Z_2, \sigma=1)$$
# $$Y = \mathcal{N}(\alpha_3 \cdot Y, \sigma=1)$$
# $$X = g(Z_1, Z_2, Z_3)$$
#
# Where g is a randomly initialized neural network. All of the alphas are in this case set to 1.

# %% [markdown]
# First off, the Y's and Z's are generated from 4 different environments. 1000 samples from each environment is drawn.

# %%
E_choice, Env, Y, Z = generate_z_and_y(np.array([0.2, 2, 3, 5]), 4000)

# %% [markdown]
# Samples from the generative process is shown in the below dataframe along with markers of which environment a sample was drawn from and the corresponding 'mean' of that environment.

# %%
df=pd.concat([p(Z), p(Y), p(Env), p(E_choice)],axis=1)
df.columns = ['Z1', 'Z2', 'Z3', 'Y', 'Env_mean', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m=df['Env'].map(colors)
df['c']=m
tdf=df
#df.round(2)

# %% [markdown]
# The below figure shows a 3d-plot of the samples in (Z1, Z2, Z3)-space coloured by environment. Use matplotlib qt instead of inline if you'd like to be able to rotate the plot etc.

# %%
# for creating a responsive plot
#%matplotlib qt
# %matplotlib inline

plot_latent_3d(df, m)
# Out:
# C:\Users\mathi\AppData\Local\Temp/ipykernel_25176/3887001011.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %% [markdown]
# Finally, the observed X-values are generated via a randomly initialized neural network with 6 hidden units and 10 output units in the next code cell.

# %% [markdown]
# # 2. Testing models in the 3 Z-case #
# This section uses synthetic data with 3 latent variables where one is a child of Y

# %%
# Generate X from Z
net=Net(3, 6, 10)
X=net(torch.from_numpy(Z.astype("float32"))).detach().numpy()

# %%
# Setup loaders
dset = EnvDataset(X[:2000],Y[:2000],E_choice[:2000])
train_loader = DataLoader(dset, batch_size=128, drop_last=True)
dset = EnvDataset(X[2000:],Y[2000:],E_choice[2000:])
test_loader = DataLoader(dset, batch_size=128, drop_last=True)
x,y,e = next(iter(train_loader))

# %%
z_dim = 3
x_y_e = 15
x_dim = 10
ye_dim = 5
y_dim = 1

# %% [markdown]
# ## 2.1 iVAE ##

# %% [markdown]
# ### 2.1.1 Setting up the iVAE code ###
# The following block defines the iVAE. Collapse this block if you'd just like to move on and see the results.

# %%
import pdb
class iVAE(nn.Module):
    def __init__(self, x, y, e, input_size, output_size, input_size_de, output_size_de, input_size_pr, output_size_pr, beta=1):
        super().__init__()
        # Encoder
        self.func_en = nn.Sequential(
                nn.Linear(in_features=input_size, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=2*output_size)
            )
        
        # Decoder
        self.func_de = nn.Sequential(
                nn.Linear(in_features=input_size_de, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=output_size_de)
            )
        
        # Prior
        self.func = nn.Sequential(
                nn.Linear(in_features=input_size_pr, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=output_size_pr*2)
            )
        
        self.normal_dist = Normal_dist()
        
        
    
    def forward(self, x, y, e, beta=1):
        # Format input
        xye=torch.cat((x, y, e), 1)
        
        # Get encoder params
        z_usigma = self.func_en(xye)
        zu, zsigma = z_usigma.chunk(2, dim = -1) # Get mu and sigma
        zsigma = zsigma.exp()
        encoder_params = zu, zsigma

        # Sample Z
        z = self.normal_dist.sample(zu, zsigma)

        # Get decoder params
        de_u = self.func_de(z)
        
        # Get prior params
        ye = torch.cat((y, e), 1)
        prior_u, prior_sigma = self.func(ye).chunk(2, axis = -1)
        prior_sigma = prior_sigma.exp()
        
        return zu, zsigma, de_u, prior_u, prior_sigma, z
    
    def elbo(self, x, y, e, beta=1):
        zu, zsigma, de_u, prior_u, prior_sigma, z = self.forward(x, y, e)
        
        # Samples from distributions with the acquired parameters
        lvar = 0.01*torch.ones(1).to('cpu')
        log_px_z = self.normal_dist.log_pdf(x, de_u, lvar) # p(x | u, sigma)
        log_qz_xye = self.normal_dist.log_pdf(z, zu, zsigma)
        log_pz_ye = self.normal_dist.log_pdf(z, prior_u, prior_sigma)

        # And compute kl and elbo
        kl = -log_qz_xye + log_pz_ye

        elbo = log_px_z + beta*kl

        return elbo.mean()

# %% [markdown]
# ### 2.1.2 iVAE results #

# %%
net_ivae=iVAE(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, 5, 3, beta=1)
x,y,e = next(iter(train_loader))
#elbo = net_ivae.elbo(x.float(),y.float(),e.float())

from torch.optim import Adam
optimizer = Adam(net_ivae.parameters(), lr=1e-3)

epochs = 1000
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    #if epoch < 20:
    #    beta = 10
    #else:
    #    beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss = net_ivae.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
    
plt.plot(train_loss)
plt.show()
# Out:
# C:\Users\mathi\anaconda3\envs\BackDec2022\lib\site-packages\torch\distributions\distribution.py:44: UserWarning: <class '__main__.Normal_dist'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# Epoch 20 of 1000
# Train loss: tensor(30.5503)
# Epoch 40 of 1000
# Train loss: tensor(15.0801)
# Epoch 60 of 1000
# Train loss: tensor(6.6103)
# Epoch 80 of 1000
# Train loss: tensor(3.0350)
# Epoch 100 of 1000
# Train loss: tensor(0.9083)
# Epoch 120 of 1000
# Train loss: tensor(0.4202)
# Epoch 140 of 1000
# Train loss: tensor(0.1599)
# Epoch 160 of 1000
# Train loss: tensor(-0.1156)
# Epoch 180 of 1000
# Train loss: tensor(-0.3501)
# Epoch 200 of 1000
# Train loss: tensor(-0.5677)
# Epoch 220 of 1000
# Train loss: tensor(-1.1430)
# Epoch 240 of 1000
# Train loss: tensor(-2.3490)
# Epoch 260 of 1000
# Train loss: tensor(-4.8302)
# Epoch 280 of 1000
# Train loss: tensor(-6.0826)
# Epoch 300 of 1000
# Train loss: tensor(-6.3798)
# Epoch 320 of 1000
# Train loss: tensor(-6.5446)
# Epoch 340 of 1000
# Train loss: tensor(-6.6503)
# Epoch 360 of 1000
# Train loss: tensor(-6.7258)
# Epoch 380 of 1000
# Train loss: tensor(-6.7802)
# Epoch 400 of 1000
# Train loss: tensor(-6.8512)
# Epoch 420 of 1000
# Train loss: tensor(-6.8918)
# Epoch 440 of 1000
# Train loss: tensor(-6.9731)
# Epoch 460 of 1000
# Train loss: tensor(-6.9912)
# Epoch 480 of 1000
# Train loss: tensor(-7.0474)
# Epoch 500 of 1000
# Train loss: tensor(-7.1190)
# Epoch 520 of 1000
# Train loss: tensor(-7.2454)
# Epoch 540 of 1000
# Train loss: tensor(-7.3049)
# Epoch 560 of 1000
# Train loss: tensor(-7.4454)
# Epoch 580 of 1000
# Train loss: tensor(-7.5655)
# Epoch 600 of 1000
# Train loss: tensor(-7.7710)
# Epoch 620 of 1000
# Train loss: tensor(-7.9026)
# Epoch 640 of 1000
# Train loss: tensor(-8.1254)
# Epoch 660 of 1000
# Train loss: tensor(-8.2288)
# Epoch 680 of 1000
# Train loss: tensor(-8.2670)
# Epoch 700 of 1000
# Train loss: tensor(-8.3682)
# Epoch 720 of 1000
# Train loss: tensor(-8.4064)
# Epoch 740 of 1000
# Train loss: tensor(-8.4103)
# Epoch 760 of 1000
# Train loss: tensor(-8.4616)
# Epoch 780 of 1000
# Train loss: tensor(-8.4494)
# Epoch 800 of 1000
# Train loss: tensor(-8.5087)
# Epoch 820 of 1000
# Train loss: tensor(-8.5131)
# Epoch 840 of 1000
# Train loss: tensor(-8.5577)
# Epoch 860 of 1000
# Train loss: tensor(-8.5388)
# Epoch 880 of 1000
# Train loss: tensor(-8.5361)
# Epoch 900 of 1000
# Train loss: tensor(-8.5656)
# Epoch 920 of 1000
# Train loss: tensor(-8.5594)
# Epoch 940 of 1000
# Train loss: tensor(-8.5767)
# Epoch 960 of 1000
# Train loss: tensor(-8.5223)
# Epoch 980 of 1000
# Train loss: tensor(-8.5777)
# Epoch 1000 of 1000
# Train loss: tensor(-8.5721)

# %%
# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 3))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    _, _, _, _, _, z = net_ivae.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_ivae=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_ivae.columns = ['Z1', 'Z2', 'Z3', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_ivae=df_ivae['Env'].map(colors)
df_ivae['c']=m
#df.round(2)

# %%
## Uncomment the qt line if you'd like to be able to rotate the plot
#%matplotlib qt
#plot_latent_3d(df_ivae, m_ivae)

# %%
# Merge dataframes together
pdf_ivae=df_ivae[['Z1', 'Z2', 'Z3']]
pdf_ivae.columns = ['pZ1', 'pZ2', 'pZ3']
cdf_ivae=tdf[['Z1', 'Z2', 'Z3']].iloc[2000:3920,:]
cdf_ivae['pZ1']=pdf_ivae['pZ1'].values
cdf_ivae['pZ2']=pdf_ivae['pZ2'].values
cdf_ivae['pZ3']=pdf_ivae['pZ3'].values

# %%
# Calculate MCC
mcc_ivae=MCC(cdf_ivae.iloc[:,:3].values, pdf_ivae.values)
MCC(cdf_ivae.iloc[:,:3].values, pdf_ivae.values)
# Out:
# [0.9109951910737291, 0.9803983847997711, 0.9924089392490937]
# [0.9109951910737291, 0.9803983847997711, 0.9924089392490937]
# 0.9612675050408647

# %% [markdown]
# ## 2.2 VAE ##

# %% [markdown]
# ### 2.2.1 Setting up VAE code ###
# Skip subsection at your own leisure.

# %%
import pdb
class VAE(nn.Module):
    def __init__(self, x, y, e, input_size, output_size, input_size_de, output_size_de, input_size_pr, output_size_pr, beta=1):
        super().__init__()
        # prior_params
        self.prior_mean = torch.zeros(1).to('cpu')
        self.logl = torch.zeros(1).to('cpu')
        
        # Encoder
        self.func_en = nn.Sequential(
                nn.Linear(in_features=input_size, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=2*output_size)
            )
        
        # Decoder
        self.func_de = nn.Sequential(
                nn.Linear(in_features=input_size_de, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=output_size_de)
            )
        
        # Prior
        self.func = nn.Sequential(
                nn.Linear(in_features=input_size_pr, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=output_size_pr*2)
            )
        
        self.normal_dist = Normal_dist()
        
    def reparametrize(self, mu, logvar):
        std = torch.exp(0.5*logvar)
        eps = self.normal_dist.sample(mu, std)
        return mu + eps * std
    
    def prior_params(self):
        return self.prior_mean, self.logl.exp()
    
    def forward(self, x, y, e, beta=1):
        # Format input
        xye=torch.cat((x, y, e), 1)
        
        # Get prior params
        prior_params = self.prior_params()
        
        # Get encoder params
        z_usigma = self.func_en(xye)
        zu, zsigma = z_usigma.chunk(2, dim = -1) # Get mu and sigma
        
        #zsigma = zsigma.exp()
        encoder_params = zu, zsigma

        # Sample Z
        z = self.reparametrize(zu, zsigma)

        # Get decoder params
        de_u = self.func_de(z)
        
        return zu, zsigma, de_u, z, prior_params

    
    def elbo(self, x, y, e, beta=1):
        zu, zsigma, de_u, z, prior_params = self.forward(x, y, e)
        # Samples from distributions with the acquired parameters
        lvar = 0.01*torch.ones(1).to('cpu')
        log_px_z = self.normal_dist.log_pdf(x, de_u, lvar) # p(x | u, sigma)
        log_qz_xy = self.normal_dist.log_pdf(z, zu, zsigma.exp())
        log_pz_ye = self.normal_dist.log_pdf(z, *prior_params)

        # And compute kl and elbo
        kl = -log_qz_xy + log_pz_ye

        elbo = log_px_z + beta*kl
        #pdb.set_trace()

        return elbo.mean()

# %%
z_dim=3
x_y_e=15
x_dim=10
net_vae=VAE(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, 5, z_dim, beta=1)

from torch.optim import Adam
optimizer = Adam(net_vae.parameters(), lr=1e-3)

epochs = 1000
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    if epoch < 20:
        beta = 10
    else:
        beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss = net_vae.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
# Out:
# C:\Users\mathi\anaconda3\envs\BackDec2022\lib\site-packages\torch\distributions\distribution.py:44: UserWarning: <class '__main__.Normal_dist'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# Epoch 20 of 1000
# Train loss: tensor(31.4949)
# Epoch 40 of 1000
# Train loss: tensor(0.1424)
# Epoch 60 of 1000
# Train loss: tensor(-2.7333)
# Epoch 80 of 1000
# Train loss: tensor(-3.7877)
# Epoch 100 of 1000
# Train loss: tensor(-4.8398)
# Epoch 120 of 1000
# Train loss: tensor(-5.8318)
# Epoch 140 of 1000
# Train loss: tensor(-6.4870)
# Epoch 160 of 1000
# Train loss: tensor(-7.0075)
# Epoch 180 of 1000
# Train loss: tensor(-7.1547)
# Epoch 200 of 1000
# Train loss: tensor(-7.3359)
# Epoch 220 of 1000
# Train loss: tensor(-7.4527)
# Epoch 240 of 1000
# Train loss: tensor(-7.5849)
# Epoch 260 of 1000
# Train loss: tensor(-7.5994)
# Epoch 280 of 1000
# Train loss: tensor(-7.7775)
# Epoch 300 of 1000
# Train loss: tensor(-7.9225)
# Epoch 320 of 1000
# Train loss: tensor(-7.9812)
# Epoch 340 of 1000
# Train loss: tensor(-8.0938)
# Epoch 360 of 1000
# Train loss: tensor(-8.1784)
# Epoch 380 of 1000
# Train loss: tensor(-8.2848)
# Epoch 400 of 1000
# Train loss: tensor(-8.3541)
# Epoch 420 of 1000
# Train loss: tensor(-8.4127)
# Epoch 440 of 1000
# Train loss: tensor(-8.5071)
# Epoch 460 of 1000
# Train loss: tensor(-8.4929)
# Epoch 480 of 1000
# Train loss: tensor(-8.5509)
# Epoch 500 of 1000
# Train loss: tensor(-8.5608)
# Epoch 520 of 1000
# Train loss: tensor(-8.6067)
# Epoch 540 of 1000
# Train loss: tensor(-8.6415)
# Epoch 560 of 1000
# Train loss: tensor(-8.6493)
# Epoch 580 of 1000
# Train loss: tensor(-8.7030)
# Epoch 600 of 1000
# Train loss: tensor(-8.7276)
# Epoch 620 of 1000
# Train loss: tensor(-8.7755)
# Epoch 640 of 1000
# Train loss: tensor(-8.7784)
# Epoch 660 of 1000
# Train loss: tensor(-8.8062)
# Epoch 680 of 1000
# Train loss: tensor(-8.8176)
# Epoch 700 of 1000
# Train loss: tensor(-8.8738)
# Epoch 720 of 1000
# Train loss: tensor(-8.8150)
# Epoch 740 of 1000
# Train loss: tensor(-8.8830)
# Epoch 760 of 1000
# Train loss: tensor(-8.9123)
# Epoch 780 of 1000
# Train loss: tensor(-8.8683)
# Epoch 800 of 1000
# Train loss: tensor(-8.8877)
# Epoch 820 of 1000
# Train loss: tensor(-8.9340)
# Epoch 840 of 1000
# Train loss: tensor(-8.9447)
# Epoch 860 of 1000
# Train loss: tensor(-8.9419)
# Epoch 880 of 1000
# Train loss: tensor(-8.9489)
# Epoch 900 of 1000
# Train loss: tensor(-8.9705)
# Epoch 920 of 1000
# Train loss: tensor(-8.9640)
# Epoch 940 of 1000
# Train loss: tensor(-8.9474)
# Epoch 960 of 1000
# Train loss: tensor(-8.9625)
# Epoch 980 of 1000
# Train loss: tensor(-8.9753)
# Epoch 1000 of 1000
# Train loss: tensor(-9.0035)

# %% [markdown]
# ### 2.2.2 VAE results ###

# %%
import matplotlib.pyplot as plt
#plt.plot(train_loss)
#plt.show()

# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 3))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    #_, _, _, _, _, z = net.forward(x.float(), y.float(), e.float(), beta=1)
    zu, zsigma, de_u, z, prior_params = net_vae.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_vae=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_vae.columns = ['Z1', 'Z2', 'Z3', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_vae=df_vae['Env'].map(colors)
df_vae['c']=m
#df.round(2)

# %%
## Uncomment the qt line if you'd like to be able to rotate the plot
#%matplotlib qt
#plot_latent_3d(df_vae, m_vae)

# %%
pdf_vae=df_vae[['Z1', 'Z2', 'Z3']]
pdf_vae.columns = ['pZ1', 'pZ2', 'pZ3']
cdf_vae=tdf[['Z1', 'Z2', 'Z3']].iloc[2000:3920,:]
#cdf=tdf[['Z1', 'Z2', 'Z3']].iloc[:1920,:]
cdf_vae['pZ1']=pdf_vae['pZ1'].values
cdf_vae['pZ2']=pdf_vae['pZ2'].values
cdf_vae['pZ3']=pdf_vae['pZ3'].values

# %%
# Calculate MCC
mcc_vae=MCC(cdf_vae.iloc[:,:3].values, pdf_vae.values)
MCC(cdf_vae.iloc[:,:3].values, pdf_vae.values)
# Out:
# [0.7695905412761287, -0.2098673903766761, 0.05200539156712429]
# [0.7695905412761287, -0.2098673903766761, 0.05200539156712429]
# ([0.7695905412761287, -0.2098673903766761, 0.05200539156712429],
#  0.1019547570777628)

# %% [markdown]
# ## 2.3 iCaRL ##

# %% [markdown]
# ### 2.3.1 iCaRL code ###
# Collapse subsection at your own leisure.

# %%
import pdb
class iCARL(nn.Module):
    def __init__(self, x, y, e, input_size, output_size, input_size_de, output_size_de, input_size_pr, output_size_pr, y_dim, beta=1):
        super().__init__()
        # Encoder
        self.func_en = nn.Sequential(
                nn.Linear(in_features=input_size, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=2*output_size)
            )
        
                # Decoder
        self.func_de = nn.Sequential(
                nn.Linear(in_features=input_size_de, out_features=6),
                nn.ReLU(),
                nn.Linear(in_features=6, out_features=output_size_de)
            )
        
        # Prior
        self.TNN = nn.Sequential(
            nn.Linear(in_features=input_size_de, out_features=6),
            nn.ReLU(),
            nn.Linear(in_features=6, out_features=y_dim*2)
        )
        
        self.lambdaNN = nn.Sequential(
            nn.Linear(in_features=ye_dim, out_features=6),
            nn.ReLU(),
            nn.Linear(in_features=6, out_features=y_dim*2)
        )
        
        self.lambdaf = nn.Sequential(
            nn.Linear(in_features=ye_dim, out_features=6),
            nn.ReLU(),
            nn.Linear(in_features=6, out_features=input_size_de*2*2)
        )
        
        self.normal_dist = Normal_dist()
        
        
    
    def forward(self, x, y, e, beta=1):
        # Format input
        xye=torch.cat((x, y, e), 1)
        
        # Get encoder params
        z_usigma = self.func_en(xye)
        zu, zsigma = z_usigma.chunk(2, dim = -1) # Get mu and sigma
        zsigma = zsigma.exp()
        encoder_params = zu, zsigma

        # Sample Z
        z = self.normal_dist.sample(zu, zsigma)

        # Get decoder params
        de_u = self.func_de(z)
        
        # Get prior params
        #ye = torch.cat((y, e), 1)
        #prior_u, prior_sigma = self.func(ye).chunk(2, axis = -1)
        #prior_sigma = prior_sigma.exp()
        
        return zu, zsigma, de_u, z
    
    def elbo(self, x, y, e, beta=1):
        # Get encoder and decoder params
        zu, zsigma, de_u, z = self.forward(x, y, e)
        
        # Samples from distributions with the acquired parameters
        lvar = 0.01*torch.ones(1).to('cpu')
        log_px_z = self.normal_dist.log_pdf(x, de_u, lvar) # p(x | u, sigma)
        log_qz_xye = self.normal_dist.log_pdf(z, zu, zsigma)
        
        z_temp = z.detach().requires_grad_(requires_grad = True)
        
        # Get prior params
        ye = torch.cat((y.detach(),e.detach()),1)
        
        TNN_params, _ = self.TNN(z_temp).chunk(2, axis = -1)
        lambdaNN_params, _ = self.lambdaNN(ye).chunk(2, axis = -1)
        lambdaf_params, _ = self.lambdaf(ye).chunk(2, axis = -1)
        
        nn_ = (TNN_params*lambdaNN_params).sum(dim = 1)
        z_cat = torch.cat((z_temp, z_temp.pow(2)), dim = 1)
        f_ = (z_cat * lambdaf_params).sum(dim = 1)
        pz_ye = nn_ + f_
        
        dpz_ye = torch.autograd.grad(pz_ye.sum(), z_temp, create_graph = True, retain_graph = True)[0]
        ddpz_ye = torch.autograd.grad(dpz_ye.sum(), z_temp, create_graph = True, retain_graph = True)[0]
        
        SM = (ddpz_ye + 0.5 * dpz_ye.pow(2)).sum(1)

        elbo = log_px_z - log_qz_xye + pz_ye.detach()

        return elbo.mean()-SM.mean(), elbo.mean(), SM.mean()

# %%
z_dim = 3
x_y_e = 15
x_dim = 10
ye_dim = 5
y_dim = 1
net_icarl=iCARL(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, ye_dim, z_dim, y_dim, beta=1)

from torch.optim import Adam
optimizer = Adam(net_icarl.parameters(), lr=1e-3)

epochs = 500
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    if epoch < 20:
        beta = 10
    else:
        beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss, elbo, SM = net_icarl.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
# Out:
# Epoch 20 of 1000
# Train loss: tensor(-5.2154)
# Epoch 40 of 1000
# Train loss: tensor(-26.8842)
# Epoch 60 of 1000
# Train loss: tensor(-28.6141)
# Epoch 80 of 1000
# Train loss: tensor(-26.1812)
# Epoch 100 of 1000
# Train loss: tensor(-26.6027)
# Epoch 120 of 1000
# Train loss: tensor(-31.2802)
# Epoch 140 of 1000
# Train loss: tensor(-27.5383)
# Epoch 160 of 1000
# Train loss: tensor(-59.7222)
# Epoch 180 of 1000
# Train loss: tensor(-66.6137)
# Epoch 200 of 1000
# Train loss: tensor(-9.7444)
# Epoch 220 of 1000
# Train loss: tensor(-52.9209)
# Epoch 240 of 1000
# Train loss: tensor(-61.4465)
# Epoch 260 of 1000
# Train loss: tensor(-46.7217)
# Epoch 280 of 1000
# Train loss: tensor(-41.9353)
# Epoch 300 of 1000
# Train loss: tensor(-52.7801)
# Epoch 320 of 1000
# Train loss: tensor(-57.8535)
# Epoch 340 of 1000
# Train loss: tensor(-50.8022)
# Epoch 360 of 1000
# Train loss: tensor(46.2609)
# Epoch 380 of 1000
# Train loss: tensor(-50.3336)
# Epoch 400 of 1000
# Train loss: tensor(-49.4984)
# Epoch 420 of 1000
# Train loss: tensor(-31.3996)
# Epoch 440 of 1000
# Train loss: tensor(-31.5024)
# Epoch 460 of 1000
# Train loss: tensor(-111.0618)
# Epoch 480 of 1000
# Train loss: tensor(-53.2279)
# Epoch 500 of 1000
# Train loss: tensor(29.9915)
# Epoch 520 of 1000
# Train loss: tensor(-40.6962)
# Epoch 540 of 1000
# Train loss: tensor(-52.4458)
# Epoch 560 of 1000
# Train loss: tensor(-48.2773)
# Epoch 580 of 1000
# Train loss: tensor(612.9407)
# Epoch 600 of 1000
# Train loss: tensor(-193.9967)
# Epoch 620 of 1000
# Train loss: tensor(-48.4464)
# Epoch 640 of 1000
# Train loss: tensor(-52.5248)
# Epoch 660 of 1000
# Train loss: tensor(-73.3238)
# Epoch 680 of 1000
# Train loss: tensor(-35.4805)
# Epoch 700 of 1000
# Train loss: tensor(-41.6194)
# Epoch 720 of 1000
# Train loss: tensor(-44.7108)
# Epoch 740 of 1000
# Train loss: tensor(21.6790)
# Epoch 760 of 1000
# Train loss: tensor(211.2385)
# Epoch 780 of 1000
# Train loss: tensor(-56.7491)
# Epoch 800 of 1000
# Train loss: tensor(-47.9460)
# Epoch 820 of 1000
# Train loss: tensor(711.7595)
# Epoch 840 of 1000
# Train loss: tensor(-22.2883)
# Epoch 860 of 1000
# Train loss: tensor(249.8886)
# Epoch 880 of 1000
# Train loss: tensor(-45.9539)
# Epoch 900 of 1000
# Train loss: tensor(-23.9340)
# Epoch 920 of 1000
# Train loss: tensor(-34.2837)
# Epoch 940 of 1000
# Train loss: tensor(142.9565)
# Epoch 960 of 1000
# Train loss: tensor(-47.2578)
# Epoch 980 of 1000
# Train loss: tensor(-44.3393)
# Epoch 1000 of 1000
# Train loss: tensor(-50.9822)

# %% [markdown]
# ### 2.3.2 iCaRL results ###

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(train_loss)
plt.show()

# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 3))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    _, _, _, z = net_icarl.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_icarl=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_icarl.columns = ['Z1', 'Z2', 'Z3', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_icarl=df_icarl['Env'].map(colors)
df_icarl['c']=m

pdf_icarl=df_icarl[['Z1', 'Z2', 'Z3']]
pdf_icarl.columns = ['pZ1', 'pZ2', 'pZ3']
#cdf=tdf[['Z1', 'Z2', 'Z3']].iloc[4000:7968,:]
cdf_icarl=tdf[['Z1', 'Z2', 'Z3']].iloc[2000:3920,:]
cdf_icarl['pZ1']=pdf_icarl['pZ1'].values
cdf_icarl['pZ2']=pdf_icarl['pZ2'].values
cdf_icarl['pZ3']=pdf_icarl['pZ3'].values
#df.round(2)

# %%
## Uncomment the qt line if you'd like to be able to rotate the plot
#%matplotlib qt
plot_latent_3d(df_icarl, m_icarl)

# creating the plot
plt.scatter(df_icarl['Z1'], df_icarl['Z2'], c=m_ivae)
# setting title and labels
plt.title("3D plot")
plt.xlabel('Z1-axis')
plt.ylabel('Z2-axis')
# Out:
# C:\Users\mathi\AppData\Local\Temp/ipykernel_27336/3887001011.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)
# Text(0, 0.5, 'Z2-axis')

# %%
# Calculate MCC
mcc_icarl, _=MCC(cdf_icarl.iloc[:,:3].values, pdf_icarl.values)
MCC(cdf_icarl.iloc[:,:3].values, pdf_icarl.values)
# Out:
# [0.030172927064223705, 0.1893667218533699, -0.9205003699024044]
# [0.030172927064223705, 0.1893667218533699, -0.9205003699024044]
# ([0.030172927064223705, 0.1893667218533699, -0.9205003699024044],
#  -0.11682678683080179)

# %% [markdown]
# ## 2.4 Summary of results of the three methods ##

# %% [markdown]
# ### 2.4.1 Posterior plots ###

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(15, 5))

ax1.scatter(df_icarl['Z1'], df_icarl['Z2'], c=m_icarl)
ax1.set_title('iCARL')
ax2.scatter(df_ivae['Z1'], df_ivae['Z2'], c=m_ivae)
ax2.set_title('iVAE')
ax3.scatter(df_vae['Z1'], df_vae['Z2'], c=m_vae)
ax3.set_title('VAE')
ax4.scatter(df['Z1'], df['Z2'], c=m)
ax4.set_title('Ground truth')
plt.show()

# %% [markdown]
# ### 2.4.2 MCC ###

# %%
mccs=np.array([mcc_icarl, mcc_vae[0], mcc_ivae[0]])
plt.bar(range(3),np.mean(np.abs(mccs),axis=1))
# Out:
# <BarContainer object of 3 artists>

# %%
mccs
# Out:
# array([[ 0.03017293,  0.18936672, -0.92050037],
#        [ 0.76959054, -0.20986739,  0.05200539],
#        [ 0.80513122, -0.30130518,  0.97680446]])

# %% [markdown]
# # 3. Case with just 2 latent variables #
# In this section the third latent variable (child of y) has been omitted and the autoencoders are once more used to regenerate the latent variables.

# %%
E_choice, Env, Y, Z = generate_z_and_y(np.array([0.2, 2, 3, 5]), 4000, three_z=False)

# %%
df=pd.concat([p(Z), p(Y), p(Env), p(E_choice)],axis=1)
df.columns = ['Z1', 'Z2', 'Y', 'Env_mean', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m=df['Env'].map(colors)
df['c']=m
tdf=df
#df.round(2)

# %%
#%matplotlib qt
#plot_latent_3d(df, m)
fig = plt.figure()


# creating the plot
plt.scatter(df['Z1'], df['Z2'], c=m)
# setting title and labels
plt.title("3D plot")
plt.xlabel('Z1-axis')
plt.ylabel('Z2-axis')
# Out:
# Text(0, 0.5, 'Z2-axis')

# %%
net=Net1(2, 6, 10)
X=net(torch.from_numpy(Z.astype("float32"))).detach().numpy()

# %%
dset = EnvDataset(X[:2000],Y[:2000],E_choice[:2000])
train_loader = DataLoader(dset, batch_size=128, drop_last=True)
dset = EnvDataset(X[2000:],Y[2000:],E_choice[2000:])
test_loader = DataLoader(dset, batch_size=128, drop_last=True)
x,y,e = next(iter(train_loader))

# %%
z_dim = 2
x_y_e = 15
x_dim = 10
ye_dim = 5
y_dim = 1

# %% [markdown]
# ## 3.1 Running the models ##

# %%
net_ivae=iVAE(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, 5, z_dim, beta=1)
x,y,e = next(iter(train_loader))
elbo = net_i.elbo(x.float(),y.float(),e.float())
elbo

from torch.optim import Adam
optimizer = Adam(net_ivae.parameters(), lr=1e-3)

epochs = 2000
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    if epoch < 20:
        beta = 10
    else:
        beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss = net_ivae.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
    
plt.plot(train_loss)
plt.show()
# Out:
# C:\Users\mathi\anaconda3\envs\BackDec2022\lib\site-packages\torch\distributions\distribution.py:44: UserWarning: <class '__main__.Normal_dist'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# Epoch 20 of 2000
# Train loss: tensor(16.7512)
# Epoch 40 of 2000
# Train loss: tensor(5.5140)
# Epoch 60 of 2000
# Train loss: tensor(0.7679)
# Epoch 80 of 2000
# Train loss: tensor(-1.4783)
# Epoch 100 of 2000
# Train loss: tensor(-2.2004)
# Epoch 120 of 2000
# Train loss: tensor(-2.5754)
# Epoch 140 of 2000
# Train loss: tensor(-3.0766)
# Epoch 160 of 2000
# Train loss: tensor(-3.5191)
# Epoch 180 of 2000
# Train loss: tensor(-4.2977)
# Epoch 200 of 2000
# Train loss: tensor(-7.9079)
# Epoch 220 of 2000
# Train loss: tensor(-8.4408)
# Epoch 240 of 2000
# Train loss: tensor(-8.6473)
# Epoch 260 of 2000
# Train loss: tensor(-8.7369)
# Epoch 280 of 2000
# Train loss: tensor(-8.9572)
# Epoch 300 of 2000
# Train loss: tensor(-9.0420)
# Epoch 320 of 2000
# Train loss: tensor(-9.1652)
# Epoch 340 of 2000
# Train loss: tensor(-9.2806)
# Epoch 360 of 2000
# Train loss: tensor(-9.3060)
# Epoch 380 of 2000
# Train loss: tensor(-9.4278)
# Epoch 400 of 2000
# Train loss: tensor(-9.4958)
# Epoch 420 of 2000
# Train loss: tensor(-9.5523)
# Epoch 440 of 2000
# Train loss: tensor(-9.5600)
# Epoch 460 of 2000
# Train loss: tensor(-9.5953)
# Epoch 480 of 2000
# Train loss: tensor(-9.6502)
# Epoch 500 of 2000
# Train loss: tensor(-9.6537)
# Epoch 520 of 2000
# Train loss: tensor(-9.6961)
# Epoch 540 of 2000
# Train loss: tensor(-9.6622)
# Epoch 560 of 2000
# Train loss: tensor(-9.6735)
# Epoch 580 of 2000
# Train loss: tensor(-9.6997)
# Epoch 600 of 2000
# Train loss: tensor(-9.7394)
# Epoch 620 of 2000
# Train loss: tensor(-9.7349)
# Epoch 640 of 2000
# Train loss: tensor(-9.7234)
# Epoch 660 of 2000
# Train loss: tensor(-9.7757)
# Epoch 680 of 2000
# Train loss: tensor(-9.7623)
# Epoch 700 of 2000
# Train loss: tensor(-9.7598)
# Epoch 720 of 2000
# Train loss: tensor(-9.7285)
# Epoch 740 of 2000
# Train loss: tensor(-9.7636)
# Epoch 760 of 2000
# Train loss: tensor(-9.7921)
# Epoch 780 of 2000
# Train loss: tensor(-9.7773)
# Epoch 800 of 2000
# Train loss: tensor(-9.8039)
# Epoch 820 of 2000
# Train loss: tensor(-9.7404)
# Epoch 840 of 2000
# Train loss: tensor(-9.7816)
# Epoch 860 of 2000
# Train loss: tensor(-9.7905)
# Epoch 880 of 2000
# Train loss: tensor(-9.7981)
# Epoch 900 of 2000
# Train loss: tensor(-9.8123)
# Epoch 920 of 2000
# Train loss: tensor(-9.7950)
# Epoch 940 of 2000
# Train loss: tensor(-9.7890)
# Epoch 960 of 2000
# Train loss: tensor(-9.7924)
# Epoch 980 of 2000
# Train loss: tensor(-9.7975)
# Epoch 1000 of 2000
# Train loss: tensor(-9.7966)
# Epoch 1020 of 2000
# Train loss: tensor(-9.8466)
# Epoch 1040 of 2000
# Train loss: tensor(-9.8236)
# Epoch 1060 of 2000
# Train loss: tensor(-9.8324)
# Epoch 1080 of 2000
# Train loss: tensor(-9.8417)
# Epoch 1100 of 2000
# Train loss: tensor(-9.8372)
# Epoch 1120 of 2000
# Train loss: tensor(-9.8166)
# Epoch 1140 of 2000
# Train loss: tensor(-9.8387)
# Epoch 1160 of 2000
# Train loss: tensor(-9.8381)
# Epoch 1180 of 2000
# Train loss: tensor(-9.8611)
# Epoch 1200 of 2000
# Train loss: tensor(-9.8436)
# Epoch 1220 of 2000
# Train loss: tensor(-9.8385)
# Epoch 1240 of 2000
# Train loss: tensor(-9.8550)
# Epoch 1260 of 2000
# Train loss: tensor(-9.8486)
# Epoch 1280 of 2000
# Train loss: tensor(-9.8325)
# Epoch 1300 of 2000
# Train loss: tensor(-9.8553)
# Epoch 1320 of 2000
# Train loss: tensor(-9.8031)
# Epoch 1340 of 2000
# Train loss: tensor(-9.8536)
# Epoch 1360 of 2000
# Train loss: tensor(-9.8710)
# Epoch 1380 of 2000
# Train loss: tensor(-9.8757)
# Epoch 1400 of 2000
# Train loss: tensor(-9.8411)
# Epoch 1420 of 2000
# Train loss: tensor(-9.8289)
# Epoch 1440 of 2000
# Train loss: tensor(-9.8406)
# Epoch 1460 of 2000
# Train loss: tensor(-9.8626)
# Epoch 1480 of 2000
# Train loss: tensor(-9.8441)
# Epoch 1500 of 2000
# Train loss: tensor(-9.8651)
# Epoch 1520 of 2000
# Train loss: tensor(-9.8499)
# Epoch 1540 of 2000
# Train loss: tensor(-9.8672)
# Epoch 1560 of 2000
# Train loss: tensor(-9.8745)
# Epoch 1580 of 2000
# Train loss: tensor(-9.8769)
# Epoch 1600 of 2000
# Train loss: tensor(-9.8744)
# Epoch 1620 of 2000
# Train loss: tensor(-9.8572)
# Epoch 1640 of 2000
# Train loss: tensor(-9.8824)
# Epoch 1660 of 2000
# Train loss: tensor(-9.8602)
# Epoch 1680 of 2000
# Train loss: tensor(-9.8541)
# Epoch 1700 of 2000
# Train loss: tensor(-9.8884)
# Epoch 1720 of 2000
# Train loss: tensor(-9.8519)
# Epoch 1740 of 2000
# Train loss: tensor(-9.8675)
# Epoch 1760 of 2000
# Train loss: tensor(-9.8736)
# Epoch 1780 of 2000
# Train loss: tensor(-9.8852)
# Epoch 1800 of 2000
# Train loss: tensor(-9.8715)
# Epoch 1820 of 2000
# Train loss: tensor(-9.8511)
# Epoch 1840 of 2000
# Train loss: tensor(-9.9024)
# Epoch 1860 of 2000
# Train loss: tensor(-9.8900)
# Epoch 1880 of 2000
# Train loss: tensor(-9.8665)
# Epoch 1900 of 2000
# Train loss: tensor(-9.8477)
# Epoch 1920 of 2000
# Train loss: tensor(-9.8691)
# Epoch 1940 of 2000
# Train loss: tensor(-9.9085)
# Epoch 1960 of 2000
# Train loss: tensor(-9.8712)
# Epoch 1980 of 2000
# Train loss: tensor(-9.8900)
# Epoch 2000 of 2000
# Train loss: tensor(-9.8787)

# %%
# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 2))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    _, _, _, _, _, z = net_ivae.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_ivae=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_ivae.columns = ['Z1', 'Z2', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_ivae=df_ivae['Env'].map(colors)
df_ivae['c']=m
#df.round(2)

# %%
# Merge dataframes together
pdf_ivae=df_ivae[['Z1', 'Z2']]
pdf_ivae.columns = ['pZ1', 'pZ2']
cdf_ivae=tdf[['Z1', 'Z2']].iloc[2000:3920,:]
cdf_ivae['pZ1']=pdf_ivae['pZ1'].values
cdf_ivae['pZ2']=pdf_ivae['pZ2'].values

# %%
# Calculate MCC
mcc_ivae=MCC(cdf_ivae.iloc[:,:2].values, pdf_ivae.values)
MCC(cdf_ivae.iloc[:,:2].values, pdf_ivae.values)
# Out:
# [0.6540892136017887, -0.9352577313661907]
# [0.6540892136017887, -0.9352577313661907]
# ([0.6540892136017887, -0.9352577313661907], -0.0702921294411005)

# %%
z_dim=2
x_y_e=15
x_dim=10
net_vae=VAE(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, 5, z_dim, beta=1)

from torch.optim import Adam
optimizer = Adam(net_vae.parameters(), lr=1e-3)

epochs = 1000
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    if epoch < 20:
        beta = 10
    else:
        beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss = net_vae.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
# Out:
# C:\Users\mathi\anaconda3\envs\BackDec2022\lib\site-packages\torch\distributions\distribution.py:44: UserWarning: <class '__main__.Normal_dist'> does not define `arg_constraints`. Please set `arg_constraints = {}` or initialize the distribution with `validate_args=False` to turn off validation.
#   warnings.warn(f'{self.__class__} does not define `arg_constraints`. ' +
# Epoch 20 of 2000
# Train loss: tensor(43.8392)
# Epoch 40 of 2000
# Train loss: tensor(11.5757)
# Epoch 60 of 2000
# Train loss: tensor(4.4917)
# Epoch 80 of 2000
# Train loss: tensor(1.8009)
# Epoch 100 of 2000
# Train loss: tensor(0.8869)
# Epoch 120 of 2000
# Train loss: tensor(0.2046)
# Epoch 140 of 2000
# Train loss: tensor(-0.6240)
# Epoch 160 of 2000
# Train loss: tensor(-2.0936)
# Epoch 180 of 2000
# Train loss: tensor(-3.5313)
# Epoch 200 of 2000
# Train loss: tensor(-4.8548)
# Epoch 220 of 2000
# Train loss: tensor(-5.6187)
# Epoch 240 of 2000
# Train loss: tensor(-6.2050)
# Epoch 260 of 2000
# Train loss: tensor(-6.6524)
# Epoch 280 of 2000
# Train loss: tensor(-7.0124)
# Epoch 300 of 2000
# Train loss: tensor(-7.3411)
# Epoch 320 of 2000
# Train loss: tensor(-7.6293)
# Epoch 340 of 2000
# Train loss: tensor(-7.8642)
# Epoch 360 of 2000
# Train loss: tensor(-8.0985)
# Epoch 380 of 2000
# Train loss: tensor(-8.2601)
# Epoch 400 of 2000
# Train loss: tensor(-8.3940)
# Epoch 420 of 2000
# Train loss: tensor(-8.5049)
# Epoch 440 of 2000
# Train loss: tensor(-8.6665)
# Epoch 460 of 2000
# Train loss: tensor(-8.7480)
# Epoch 480 of 2000
# Train loss: tensor(-8.9002)
# Epoch 500 of 2000
# Train loss: tensor(-8.9920)
# Epoch 520 of 2000
# Train loss: tensor(-9.1174)
# Epoch 540 of 2000
# Train loss: tensor(-9.2868)
# Epoch 560 of 2000
# Train loss: tensor(-9.3465)
# Epoch 580 of 2000
# Train loss: tensor(-9.4550)
# Epoch 600 of 2000
# Train loss: tensor(-9.4940)
# Epoch 620 of 2000
# Train loss: tensor(-9.5130)
# Epoch 640 of 2000
# Train loss: tensor(-9.5715)
# Epoch 660 of 2000
# Train loss: tensor(-9.5572)
# Epoch 680 of 2000
# Train loss: tensor(-9.6125)
# Epoch 700 of 2000
# Train loss: tensor(-9.6056)
# Epoch 720 of 2000
# Train loss: tensor(-9.6116)
# Epoch 740 of 2000
# Train loss: tensor(-9.6523)
# Epoch 760 of 2000
# Train loss: tensor(-9.6697)
# Epoch 780 of 2000
# Train loss: tensor(-9.6273)
# Epoch 800 of 2000
# Train loss: tensor(-9.6289)
# Epoch 820 of 2000
# Train loss: tensor(-9.6761)
# Epoch 840 of 2000
# Train loss: tensor(-9.6989)
# Epoch 860 of 2000
# Train loss: tensor(-9.7098)
# Epoch 880 of 2000
# Train loss: tensor(-9.6786)
# Epoch 900 of 2000
# Train loss: tensor(-9.7005)
# Epoch 920 of 2000
# Train loss: tensor(-9.6994)
# Epoch 940 of 2000
# Train loss: tensor(-9.6910)
# Epoch 960 of 2000
# Train loss: tensor(-9.7186)
# Epoch 980 of 2000
# Train loss: tensor(-9.7168)
# Epoch 1000 of 2000
# Train loss: tensor(-9.7289)
# Epoch 1020 of 2000
# Train loss: tensor(-9.7271)
# Epoch 1040 of 2000
# Train loss: tensor(-9.7242)
# Epoch 1060 of 2000
# Train loss: tensor(-9.7502)
# Epoch 1080 of 2000
# Train loss: tensor(-9.7687)
# Epoch 1100 of 2000
# Train loss: tensor(-9.7403)
# Epoch 1120 of 2000
# Train loss: tensor(-9.7533)
# Epoch 1140 of 2000
# Train loss: tensor(-9.7612)
# Epoch 1160 of 2000
# Train loss: tensor(-9.7533)
# Epoch 1180 of 2000
# Train loss: tensor(-9.7569)
# Epoch 1200 of 2000
# Train loss: tensor(-9.7218)
# Epoch 1220 of 2000
# Train loss: tensor(-9.7914)
# Epoch 1240 of 2000
# Train loss: tensor(-9.7706)
# Epoch 1260 of 2000
# Train loss: tensor(-9.7554)
# Epoch 1280 of 2000
# Train loss: tensor(-9.7572)
# Epoch 1300 of 2000
# Train loss: tensor(-9.7431)
# Epoch 1320 of 2000
# Train loss: tensor(-9.8045)
# Epoch 1340 of 2000
# Train loss: tensor(-9.7566)
# Epoch 1360 of 2000
# Train loss: tensor(-9.7659)
# Epoch 1380 of 2000
# Train loss: tensor(-9.7973)
# Epoch 1400 of 2000
# Train loss: tensor(-9.7840)
# Epoch 1420 of 2000
# Train loss: tensor(-9.7543)
# Epoch 1440 of 2000
# Train loss: tensor(-9.7930)
# Epoch 1460 of 2000
# Train loss: tensor(-9.7569)
# Epoch 1480 of 2000
# Train loss: tensor(-9.7522)
# Epoch 1500 of 2000
# Train loss: tensor(-9.7675)
# Epoch 1520 of 2000
# Train loss: tensor(-9.7941)
# Epoch 1540 of 2000
# Train loss: tensor(-9.7742)
# Epoch 1560 of 2000
# Train loss: tensor(-9.7948)
# Epoch 1580 of 2000
# Train loss: tensor(-9.8060)
# Epoch 1600 of 2000
# Train loss: tensor(-9.8133)
# Epoch 1620 of 2000
# Train loss: tensor(-9.8166)
# Epoch 1640 of 2000
# Train loss: tensor(-9.8365)
# Epoch 1660 of 2000
# Train loss: tensor(-9.8215)
# Epoch 1680 of 2000
# Train loss: tensor(-9.7853)
# Epoch 1700 of 2000
# Train loss: tensor(-9.7825)
# Epoch 1720 of 2000
# Train loss: tensor(-9.7966)
# Epoch 1740 of 2000
# Train loss: tensor(-9.7957)
# Epoch 1760 of 2000
# Train loss: tensor(-9.8256)
# Epoch 1780 of 2000
# Train loss: tensor(-9.7856)
# Epoch 1800 of 2000
# Train loss: tensor(-9.8135)
# Epoch 1820 of 2000
# Train loss: tensor(-9.7870)
# Epoch 1840 of 2000
# Train loss: tensor(-9.8031)
# Epoch 1860 of 2000
# Train loss: tensor(-9.8068)
# Epoch 1880 of 2000
# Train loss: tensor(-9.8116)
# Epoch 1900 of 2000
# Train loss: tensor(-9.8371)
# Epoch 1920 of 2000
# Train loss: tensor(-9.8187)
# Epoch 1940 of 2000
# Train loss: tensor(-9.8105)
# Epoch 1960 of 2000
# Train loss: tensor(-9.8442)
# Epoch 1980 of 2000
# Train loss: tensor(-9.8190)
# Epoch 2000 of 2000
# Train loss: tensor(-9.8270)

# %%
import matplotlib.pyplot as plt
#plt.plot(train_loss)
#plt.show()

# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 2))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    #_, _, _, _, _, z = net.forward(x.float(), y.float(), e.float(), beta=1)
    zu, zsigma, de_u, z, prior_params = net_vae.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_vae=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_vae.columns = ['Z1', 'Z2', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_vae=df_vae['Env'].map(colors)
df_vae['c']=m
#df.round(2)

# %%
pdf_vae=df_vae[['Z1', 'Z2']]
pdf_vae.columns = ['pZ1', 'pZ2']
cdf_vae=tdf[['Z1', 'Z2']].iloc[2000:3920,:]
#cdf=tdf[['Z1', 'Z2', 'Z3']].iloc[:1920,:]
cdf_vae['pZ1']=pdf_vae['pZ1'].values
cdf_vae['pZ2']=pdf_vae['pZ2'].values

# %%
# Calculate MCC
mcc_vae=MCC(cdf_vae.iloc[:,:2].values, pdf_vae.values)
MCC(cdf_vae.iloc[:,:2].values, pdf_vae.values)
# Out:
# [-0.3017737795770035, -0.9466089850926742]
# [-0.3017737795770035, -0.9466089850926742]
# ([-0.3017737795770035, -0.9466089850926742], -0.3120956911674194)

# %%
z_dim = 2
x_y_e = 15
x_dim = 10
ye_dim = 5
y_dim = 1
net_icarl=iCARL(x.float(), y.float(), e.float(), x_y_e, z_dim, z_dim, x_dim, ye_dim, z_dim, y_dim, beta=1)

from torch.optim import Adam
optimizer = Adam(net_icarl.parameters(), lr=1e-3)

epochs = 1000
train_loss = torch.zeros(epochs)
elbo_loss = torch.zeros(epochs)
SM_loss = torch.zeros(epochs)
pz_ye_loss = torch.zeros(epochs)

for epoch in range(epochs):
    epoch_loss = 0
    if epoch < 20:
        beta = 10
    else:
        beta = 10
    for x,y,e in train_loader:
        optimizer.zero_grad()
        loss, elbo, SM = net_icarl.elbo(x.float(), y.float(), e.float())
        loss.mul(-1).backward()
        optimizer.step()
        epoch_loss += loss.mul(-1).detach()
        
    if (epoch+1)%20 == 0:
        print('Epoch', epoch+1, 'of', epochs)
        print('Train loss:', epoch_loss/len(train_loader))
    train_loss[epoch] = epoch_loss/len(train_loader)
# Out:
# Epoch 20 of 1000
# Train loss: tensor(-26.6606)
# Epoch 40 of 1000
# Train loss: tensor(-76.1612)
# Epoch 60 of 1000
# Train loss: tensor(-86.5545)
# Epoch 80 of 1000
# Train loss: tensor(-88.5308)
# Epoch 100 of 1000
# Train loss: tensor(-88.4220)
# Epoch 120 of 1000
# Train loss: tensor(-88.0568)
# Epoch 140 of 1000
# Train loss: tensor(-88.1171)
# Epoch 160 of 1000
# Train loss: tensor(-88.9981)
# Epoch 180 of 1000
# Train loss: tensor(-91.2235)
# Epoch 200 of 1000
# Train loss: tensor(-95.1041)
# Epoch 220 of 1000
# Train loss: tensor(-101.6276)
# Epoch 240 of 1000
# Train loss: tensor(-109.5931)
# Epoch 260 of 1000
# Train loss: tensor(-118.2001)
# Epoch 280 of 1000
# Train loss: tensor(-126.2824)
# Epoch 300 of 1000
# Train loss: tensor(-132.6628)
# Epoch 320 of 1000
# Train loss: tensor(-136.4470)
# Epoch 340 of 1000
# Train loss: tensor(-138.1339)
# Epoch 360 of 1000
# Train loss: tensor(-138.1794)
# Epoch 380 of 1000
# Train loss: tensor(-135.8586)
# Epoch 400 of 1000
# Train loss: tensor(-130.8193)
# Epoch 420 of 1000
# Train loss: tensor(-123.7504)
# Epoch 440 of 1000
# Train loss: tensor(-116.6573)
# Epoch 460 of 1000
# Train loss: tensor(-110.3553)
# Epoch 480 of 1000
# Train loss: tensor(-104.8251)
# Epoch 500 of 1000
# Train loss: tensor(-100.0953)
# Epoch 520 of 1000
# Train loss: tensor(-96.2994)
# Epoch 540 of 1000
# Train loss: tensor(-93.2987)
# Epoch 560 of 1000
# Train loss: tensor(-91.1013)
# Epoch 580 of 1000
# Train loss: tensor(-89.4520)
# Epoch 600 of 1000
# Train loss: tensor(-87.7203)
# Epoch 620 of 1000
# Train loss: tensor(-86.6089)
# Epoch 640 of 1000
# Train loss: tensor(-85.6546)
# Epoch 660 of 1000
# Train loss: tensor(-84.9157)
# Epoch 680 of 1000
# Train loss: tensor(-83.9000)
# Epoch 700 of 1000
# Train loss: tensor(-82.9867)
# Epoch 720 of 1000
# Train loss: tensor(-81.9596)
# Epoch 740 of 1000
# Train loss: tensor(-81.2754)
# Epoch 760 of 1000
# Train loss: tensor(-80.9777)
# Epoch 780 of 1000
# Train loss: tensor(-80.5522)
# Epoch 800 of 1000
# Train loss: tensor(-80.1147)
# Epoch 820 of 1000
# Train loss: tensor(-79.3741)
# Epoch 840 of 1000
# Train loss: tensor(-79.2326)
# Epoch 860 of 1000
# Train loss: tensor(-78.7681)
# Epoch 880 of 1000
# Train loss: tensor(-78.8498)
# Epoch 900 of 1000
# Train loss: tensor(-79.1095)
# Epoch 920 of 1000
# Train loss: tensor(-79.5093)
# Epoch 940 of 1000
# Train loss: tensor(-79.8567)
# Epoch 960 of 1000
# Train loss: tensor(-80.3502)
# Epoch 980 of 1000
# Train loss: tensor(-80.8333)
# Epoch 1000 of 1000
# Train loss: tensor(-81.3139)

# %%
# %matplotlib inline
plt.plot(train_loss)
plt.show()

# get z
loader = test_loader
latent_variables = torch.zeros((len(train_loader)*128, 2))
envs_samp = np.zeros((len(train_loader)*128, 4))
i = 0
for x,y,e in loader:
    _, _, _, z = net_icarl.forward(x.float(), y.float(), e.float(), beta=1)
    latent_variables[i*128:i*128+128,:] = z.detach()
    envs_samp[i*128:i*128+128,:] = e.squeeze().numpy().astype(int)
    i+=1
    
df_icarl=pd.concat([p(latent_variables.detach().numpy()), p(np.argmax(envs_samp, axis=1))],axis=1)
df_icarl.columns = ['Z1', 'Z2', 'Env']
colors = {0: 'red', 1: 'blue', 2: 'green', 3: 'yellow'}
m_icarl=df_icarl['Env'].map(colors)
df_icarl['c']=m

pdf_icarl=df_icarl[['Z1', 'Z2']]
pdf_icarl.columns = ['pZ1', 'pZ2']
cdf_icarl=tdf[['Z1', 'Z2']].iloc[2000:3920,:]
cdf_icarl['pZ1']=pdf_icarl['pZ1'].values
cdf_icarl['pZ2']=pdf_icarl['pZ2'].values
#df.round(2)

# %%
# Calculate MCC
mcc_icarl, _=MCC(cdf_icarl.iloc[:,:2].values, pdf_icarl.values)
MCC(cdf_icarl.iloc[:,:2].values, pdf_icarl.values)
# Out:
# [-0.9322071754141856, -0.27855352022741736]
# [-0.9322071754141856, -0.27855352022741736]
# ([-0.9322071754141856, -0.27855352022741736], -0.30269017391040076)

# %% [markdown]
# ## 2.4 Summary of results of the three methods ##

# %% [markdown]
# ### 2.4.1 Posterior plots ###

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize=(15, 5))

ax1.scatter(df_icarl['Z1'], df_icarl['Z2'], c=m_icarl)
ax1.set_title('iCARL')
ax2.scatter(df_ivae['Z1'], df_ivae['Z2'], c=m_ivae)
ax2.set_title('iVAE')
ax3.scatter(df_vae['Z1'], df_vae['Z2'], c=m_vae)
ax3.set_title('VAE')
ax4.scatter(df['Z1'], df['Z2'], c=m)
ax4.set_title('Ground truth')
plt.show()

# %% [markdown]
# ### 2.4.2 MCC ###

# %%
mccs=np.array([mcc_icarl, mcc_vae[0], mcc_ivae[0]])
plt.bar(range(3),np.mean(np.abs(mccs),axis=1))
# Out:
# <BarContainer object of 3 artists>

# %%
mccs
# Out:
# array([[-0.93220718, -0.27855352],
#        [-0.30177378, -0.94660899],
#        [ 0.65408921, -0.93525773]])
