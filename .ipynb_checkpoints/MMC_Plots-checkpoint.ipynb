# %%
# %run DL_func.ipynb

# %%
def plot_MCC(mcc_model, mcc_mean, mcc_var, colour):
    """_summary_

    Args:
        mcc_model (list): names of models that MCC was performed on
        mcc_mean (list): the returned value of the MCC function
        mcc_var (list): the variance that corresponds with the mean values given above
    """
    plt.figure(figsize=(6,4), dpi=100)
    plt.bar(mcc_model, mcc_mean, yerr=mcc_var, color=colour)

# %%
mcc_model=['VAE', 'iVAE', 'iCaRL']

# %% [markdown]
# # 100 Epochs #

# %%
our_3z=pd.DataFrame(np.array([[.84, .72, .97], [.80, .96, .98], [.86, .96, .98]]).T)
our_3z.columns=['VAE', 'iVAE', 'iCaRL']

our_2z=pd.DataFrame(np.array([[.74, .92], [.92, .94], [.90, .94]]).T)
our_2z.columns=['VAE', 'iVAE', 'iCaRL']

# %%
Thea_3z=pd.DataFrame(np.array([[.74, .77, .96], [.79, .87, .91], [.79, .87, .91]]).T)
Thea_3z.columns=['VAE', 'iVAE', 'iCaRL']

Thea_2z=pd.DataFrame(np.array([[.70, .90], [.95, .93], [.78, .88]]).T)
Thea_2z.columns=['VAE', 'iVAE', 'iCaRL']

# %%
plot_MCC(mcc_model, our_3z.mean(), our_3z.var(), colour='blue')

# %%
plot_MCC(mcc_model, our_2z.mean(), our_2z.var(), colour='red')

# %%
plot_MCC(mcc_model, Thea_3z.mean(), Thea_3z.var(), colour='blue')

# %%
plot_MCC(mcc_model, Thea_2z.mean(), Thea_2z.var(), colour = 'red')

# %% [markdown]
# # 1000 Epochs #

# %%
our_3z=pd.DataFrame(np.array([[.87, .52, .24], [.87, .68, .99], [.82, .98, .99]]).T)
our_3z.columns=['VAE', 'iVAE', 'iCaRL']

our_2z=pd.DataFrame(np.array([[.93, .35], [.94, .98], [.75, .93]]).T)
our_2z.columns=['VAE', 'iVAE', 'iCaRL']

# %%
plot_MCC(mcc_model, our_3z.mean(), our_3z.var(), colour='blue')

# %%
plot_MCC(mcc_model, our_2z.mean(), our_2z.var(), colour='red')
