# %%
# %run DL_func.ipynb

# %%
def plot_MCC(mcc_model, mcc_mean, mcc_var):
    """_summary_

    Args:
        mcc_model (list): names of models that MCC was performed on
        mcc_mean (list): the returned value of the MCC function
        mcc_var (list): the variance that corresponds with the mean values given above
    """
    plt.figure(figsize=(6,4), dpi=100)
    plt.bar(mcc_model, mcc_mean, yerr=mcc_var, color='red')

# %%
mcc_model=['VAE', 'iVAE', 'iCaRL']

# %%
our_3z=pd.DataFrame(np.array([[0.45, 0.92, 0.10], [.52, .91, .97], [.82, .91, .89]]).T)
our_3z.columns=['VAE', 'iVAE', 'iCaRL']

our_2z=pd.DataFrame(np.array([[0.92, 0.07], [.91, .00], [.93, .07]]).T)
our_2z.columns=['VAE', 'iVAE', 'iCaRL']

# %%
Thea_3z=pd.DataFrame(np.array([[.24, .89, .02], [.68, .63, .15], [.66, .91, .009]]).T)
Thea_3z.columns=['VAE', 'iVAE', 'iCaRL']

Thea_2z=pd.DataFrame(np.array([[.83, .06], [.15, .94], [.37, .68]]).T)
Thea_2z.columns=['VAE', 'iVAE', 'iCaRL']

# %%
plot_MCC(mcc_model, our_3z.mean(), our_3z.var())

# %%
plot_MCC(mcc_model, our_2z.mean(), our_2z.var())

# %%
plot_MCC(mcc_model, Thea_3z.mean(), Thea_3z.var())

# %%
plot_MCC(mcc_model, Thea_2z.mean(), Thea_2z.var())
